# %% [markdown]
# # Book settings
# title: Machine Learning
# author: Gajanesh
# copyright: "2025"
# logo: "images/logo.png"
# exclude_patterns:
#   - _build
#   - Thumbs.db
#   - .DS_Store
#   - "**.ipynb_checkpoints"
# only_build_toc_files: false
#
# # Execution settings
# execute:
#   execute_notebooks: auto          # Changed from 'off' to process notebooks
#   cache: _build/.jupyter_cache/
#   exclude_patterns: []
#   timeout: 30
#   run_in_temp: false
#   allow_errors: false
#   stderr_output: show
#
# # HTML-specific settings
# html:
#   favicon: "images/favicon.ico"
#   use_edit_page_button: true
#   use_repository_button: true
#   use_issues_button: true
#   use_multitoc_numbering: true
#   extra_footer: ""
#   home_page_in_navbar: true
#   extra_css:
#     - _static/custom.css
#   extra_head:
#     - "https://fonts.googleapis.com/css2?family=Inter:wght@400;600;700&display=swap"
#   baseurl: ""
#   analytics:
#     plausible_analytics_domain: ""
#     plausible_analytics_url: "https://plausible.io/js/script.js"
#     google_analytics_id: "UA-XXXXX-Y"
#   comments:
#     hypothesis: false
#     utterances: false
#   announcement: "Welcome to the Machine Learning Book!"
#   use_sidebar: true
#   sidebar:
#     nav_title: Table of Contents
#     sticky: true
#
# # Notebook rendering settings
# nb_render_priority:
#   - "html"  # Show HTML rendering first
#   - "ipynb" # Fallback to raw notebook
#
# # LaTeX-specific settings
# latex:
#   latex_engine: xelatex
#   use_jupyterbook_latex: true
#
# # Launch button settings
# launch_buttons:
#   notebook_interface: classic
#   binderhub_url: "https://mybinder.org"
#   jupyterhub_url: ""
#   thebe: false
#   colab_url: "https://colab.research.google.com"
#   deepnote_url: ""
#
# # Repository settings
# repository:
#   url: https://github.com/coding-fame/jupyter-book
#   path_to_book: ""
#   branch: main
#
# # Advanced settings
# sphinx:
#   extra_extensions:
#     - sphinx_copybutton
#     - myst_nb  # Added MyST-NB extension
#   recursive_update: false
#   config:
#     mathjax_path: "https://cdn.jsdelivr.net/npm/mathjax@3/es5/tex-mml-chtml.js"
#     mathjax3_config:
#       tex:
#         inlineMath: [['$', '$'], ['\\(', '\\)']]
#         displayMath: [['$$', '$$'], ['\\[', '\\]']]
#         processEscapes: true
#     source_suffix: [".md", ".ipynb"]  # Added to process notebooks
#     nb_render_priority: ["html", "ipynb"]  # Render priority
